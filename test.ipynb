# %%
import pandas as pd
import numpy as np

# %%
import os
cwd = os.getcwd()
df = pd.read_csv(os.path.join(cwd, "data", "final_data.csv"))
df
# Out:
#     symbol                            sector  \
# 0      1A0        Cyclical Consumer Services
# 1      1A1                  Industrial Goods
# 2      1A4                 Holding Companies
# 3      1AZ        Cyclical Consumer Services
# 4      1B0        Cyclical Consumer Services
# ..     ...                               ...
# 589    ZXY  Industrial & Commercial Services
# 590    NaN                            Energy
# 591    NaN                       Industrials
# 592    NaN            Consumer Non-Cyclicals
# 593    NaN                        Healthcare
#
#                             sub_sector investing_symbol
# 0                   Restaurants & Bars              NaN
# 1     Industrial Machinery & Equipment              NaN
# 2         Investment Holding Companies              NaN
# 3                  Consumer Publishing              NaN
# 4             Entertainment Production              NaN
# ..                                 ...              ...
# ...
